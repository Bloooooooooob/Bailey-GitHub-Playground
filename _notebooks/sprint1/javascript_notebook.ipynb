# %%
Basic Code

console.log("");
Displays whatever is in the parantheses in the terminal

var variableName = content;
Makes a variable

number.toString();
Makes a number into a string value, good for visual counters

Number(stringOrSomething);
Makes whatever is in the parentheses into a number

function funcName(var1,var2,ect...){function code here}
A function is pretty much a variable but for code

funcName(var1, var2, ect...);
Calls function which runs the code inside of the function

return value;
Returns value from function

var audio = new Audio("audiofile")
Adds audio into your website

audio.play();
Plays the audio that is already in your website

HTML Coding

document.GetElementById("id")
Lets you get whatever element in the html website with the id as you put and you can change it.

___.innerHTML = "text/otherstuff"
Lets you change whatever is inside of an html thing like changing text

___.style = "styleProp: prop;"
Changes the style of an html element

___.value
Gets whatever is in a textbox for user input

Everything about if statements

if(term){code}
If the term is true then the code will run that is in the curly brackets

else if(term){code}
You put this after an if statement and it will follow the same rules as a regular if statement but just adds on

else{code}
This will run the code if everything else in the if statements are false

if(term1 == term2){code}
If term1 is equal to term2, the code will play

if(term1 != term2){code}
If term1 is not equal to term2, the code will play

if(term1 < term2){code}
If term1 is less than term2, the code will play

if(term1 <= term2){code}
If term1 is less than or equal to term2, the code will play

if(term1 > term2){code}
If term1 is greater than term2, the code will play

if(term1 >= term2){code}
If term1 is greater than or equal to term2, the code will play

if(term1 && term2){code}
If term1 and term2 are true, the code will play

if(term1 || term2){code}
If term1 or term2 are true, the code will play
